# %%
import pandas as pd

# Sample dialogues for training
train_data = [
    # Order Issue
    {"conversation": "My order is delayed, can you help me with it? I urgently need it.", "intent": "order_issue"},
    {"conversation": "The product I received is not what I expected. I want a refund or replacement.", "intent": "order_issue"},
    {"conversation": "I accidentally ordered the wrong item. Can I cancel the order?", "intent": "order_issue"},
    {"conversation": "My package is lost in transit. What should I do now?", "intent": "order_issue"},
    {"conversation": "There's an error in the billing amount of my order. Can you rectify it?", "intent": "order_issue"},
    {"conversation": "I received a damaged product. How can I return or exchange it?", "intent": "order_issue"},
    {"conversation": "I haven't received my order yet. Can you provide an update on its status?", "intent": "order_issue"},
    {"conversation": "I need to change the shipping address for my order. Is it possible?", "intent": "order_issue"},
    {"conversation": "The order I placed is missing some items. Can you help me with it?", "intent": "order_issue"},
    {"conversation": "The delivery date for my order has passed, but I haven't received it yet. What's happening?", "intent": "order_issue"},
    {"conversation": "I received the wrong size of the product in my order. Can I get a replacement?", "intent": "order_issue"},
    {"conversation": "I need to update my contact information for delivery purposes. How can I do that?", "intent": "order_issue"},
    {"conversation": "The product I received is defective. What is the process for returning it?", "intent": "order_issue"},
    {"conversation": "My order has been marked as delivered, but I haven't received it. What should I do?", "intent": "order_issue"},
    {"conversation": "I want to track the delivery status of my order. How can I do that?", "intent": "order_issue"},

    # Small Talk
    {"conversation": "Hello! How's your day going? I hope it's going well.", "intent": "small_talk"},
    {"conversation": "Good morning! I hope you have a great day ahead.", "intent": "small_talk"},
    {"conversation": "Hi there! Just wanted to check in and say hi.", "intent": "small_talk"},
    {"conversation": "Hey! How's everything going? Anything exciting happening?", "intent": "small_talk"},
    {"conversation": "Hi! How are you doing today? Anything interesting going on?", "intent": "small_talk"},
    {"conversation": "Hello! How's the weather at your place? It's sunny here.", "intent": "small_talk"},
    {"conversation": "Hey there! Just wanted to drop by and say hello.", "intent": "small_talk"},
    {"conversation": "Good afternoon! Hope you're having a wonderful day.", "intent": "small_talk"},
    {"conversation": "Hi! How's life treating you? Hope everything's going well.", "intent": "small_talk"},
    {"conversation": "Hello! What's up? Anything exciting happening in your life?", "intent": "small_talk"},
    {"conversation": "Hey! How's your week going so far? Anything interesting going on?", "intent": "small_talk"},
    {"conversation": "Hi there! Hope you're having a fantastic day!", "intent": "small_talk"},
    {"conversation": "Hey! How's your day been so far? Anything new and exciting?", "intent": "small_talk"},
    {"conversation": "Hello! How's everything going? Hope you're doing well.", "intent": "small_talk"},
    {"conversation": "Hi! How's your day shaping up? Hope it's going smoothly.", "intent": "small_talk"},

    # Delivery Change
    {"conversation": "I need to change the delivery address for my order. Can you assist me with that?", "intent": "delivery_change"},
    {"conversation": "The delivery date for my order doesn't work for me. Can I reschedule it?", "intent": "delivery_change"},
    {"conversation": "I want to switch to express delivery for my order. How can I do that?", "intent": "delivery_change"},
    {"conversation": "The delivery time slot I selected is no longer suitable. Can I change it?", "intent": "delivery_change"},
    {"conversation": "I need to update the delivery instructions for my order. How do I do that?", "intent": "delivery_change"},
    {"conversation": "I won't be available to receive my order on the scheduled delivery date. Can it be postponed?", "intent": "delivery_change"},
    {"conversation": "I want to change the delivery method from standard to expedited. Is that possible?", "intent": "delivery_change"},
    {"conversation": "The delivery address provided is incorrect. Can I correct it before the order ships?", "intent": "delivery_change"},
    {"conversation": "I'd like to change the delivery location to my workplace. How do I do that?", "intent": "delivery_change"},
    {"conversation": "The delivery instructions I provided earlier need to be revised. How can I update them?", "intent": "delivery_change"},
    {"conversation": "I need to specify a safe place for delivery in case I'm not home. How can I do that?", "intent": "delivery_change"},
    {"conversation": "The delivery time frame I selected is too broad. Can I narrow it down?", "intent": "delivery_change"},
    {"conversation": "I need to change the delivery date for my order due to unforeseen circumstances. How do I proceed?", "intent": "delivery_change"},
    {"conversation": "The delivery address needs to be changed to a different city. Can I do that online?", "intent": "delivery_change"},
    {"conversation": "I'd like to add special delivery instructions for my order. How can I do that?", "intent": "delivery_change"},
]

# Convert the list of dictionaries into a DataFrame
train_df = pd.DataFrame(train_data)

# Save DataFrame to CSV
train_df.to_csv("C:/Users/umesh.malviya1/Downloads/intent_classification_data.csv", columns=["conversation", "intent"], index=False)
